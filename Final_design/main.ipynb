# %%
#imports
import os 
from tqdm import tqdm

# %%
def create_card():
    pass

# %%
ls
# Out:
# azbook_anl/         Aznews_axaraz/  az_wiki/
# azbook_ebooks/      Aznews_Kulis/   corpus_manage.ipynb
# azbook_kitabyurdu/  Aznews_lentaz/  main.ipynb

# %%
os.getcwd()
# Out:
# '/home/g202103810/Desktop/AZGPT_Corpus/Aznews_Kulis'

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/Aznews_Kulis/renamed_files'

# %%
kulis_az_dict = {}

kulis_az = []

for text_name in tqdm(os.listdir(main_path)):
    with open(os.path.join(main_path,text_name), 'r') as file:
        text = file.read()
    kulis_az_dict['id'] = text_name[:-4]
    kulis_az_dict['text'] = text.replace('\n', "")
    kulis_az_dict['source'] = 'az_news'
    kulis_az_dict['reliability'] = 5
    kulis_az_dict['license'] = 'Public Domain'
    
    kulis_az.append(kulis_az_dict)
# Out:
# 100%|██████████████████████████████████| 30808/30808 [00:00<00:00, 35350.71it/s]

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/Aznews_lentaz/renamed_files'

# %%
lent_az_dict = {}

lent_az = []

for text_name in tqdm(os.listdir(main_path)):
    with open(os.path.join(main_path,text_name), 'r') as file:
        text = file.read()
    lent_az_dict['id'] = text_name[:-4]
    lent_az_dict['text'] = text.replace('\n', "")
    lent_az_dict['source'] = 'az_news'
    lent_az_dict['reliability'] = 5
    lent_az_dict['license'] = 'Public Domain'
    
    lent_az.append(lent_az_dict)
# Out:
# 100%|██████████████████████████████████| 62622/62622 [00:01<00:00, 51611.55it/s]

# %%
len(lent_az)
# Out:
# 62622

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/az_wiki/renamed_files'

# %%
az_wiki_dict = {}

az_wiki = []

for text_name in tqdm(os.listdir(main_path)):
    with open(os.path.join(main_path,text_name), 'r') as file:
        text = file.read()
    az_wiki_dict['id'] = text_name[:-4]
    az_wiki_dict['text'] = text.replace('\n', "")
    az_wiki_dict['source'] = 'az_wiki'
    az_wiki_dict['reliability'] = 4
    az_wiki_dict['license'] = 'Public Domain'
    
    az_wiki.append(az_wiki_dict)
# Out:
# 100%|██████████████████████████████████| 98882/98882 [00:02<00:00, 48999.20it/s]

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/Aznews_axaraz/renamed_files'

# %%
axar_az_dict = {}

axar_az = []

for text_name in tqdm(os.listdir(main_path)):
    with open(os.path.join(main_path,text_name), 'r') as file:
        text = file.read()
    axar_az_dict['id'] = text_name[:-4]
    axar_az_dict['text'] = text.replace('\n', "")
    axar_az_dict['source'] = 'az_news'
    axar_az_dict['reliability'] = 5
    axar_az_dict['license'] = 'Public Domain'
    
    axar_az.append(axar_az_dict)
# Out:
# 100%|████████████████████████████████| 143448/143448 [00:02<00:00, 58486.79it/s]

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/azbook_anl/data_anl'

# %%
azbook_anl_dict = {}

azbook_anl  = []

for text_name in tqdm(os.listdir(main_path)):
    with open(os.path.join(main_path,text_name), 'r') as file:
        text = file.read()
    azbook_anl_dict['id'] = text_name[:-4]
    azbook_anl_dict['text'] = text.replace('\n', "")
    azbook_anl_dict['source'] = 'az_books'
    azbook_anl_dict['reliability'] = 3
    azbook_anl_dict['license'] = 'Public Domain'
    
    azbook_anl.append(azbook_anl_dict)
# Out:
# 100%|████████████████████████████████| 314804/314804 [00:04<00:00, 68130.72it/s]

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/azbook_ebooks/data'

# %%
azbook_ebooks_dict = {}

azbook_ebooks  = []

for text_name in tqdm(os.listdir(main_path)):
    with open(os.path.join(main_path,text_name), 'r') as file:
        text = file.read()
    azbook_ebooks_dict['id'] = text_name[:-4]
    azbook_ebooks_dict['text'] = text.replace('\n', "")
    azbook_ebooks_dict['source'] = 'az_books'
    azbook_ebooks_dict['reliability'] = 3
    azbook_ebooks_dict['license'] = 'Public Domain'
    
    azbook_ebooks.append(azbook_ebooks_dict)
# Out:
# 100%|██████████████████████████████| 1139591/1139591 [00:17<00:00, 66734.67it/s]

# %%
main_path = '/home/g202103810/Desktop/AZGPT_Corpus/azbook_kitabyurdu/data_kitabyurdu'

# %%
azbook_kitabyurdu_dict = {}

https://mega.nz/file/tyR1UK4K#hNFOotF9MuVoJAHf45KDamG17ZOo4lfsdii4zz7NDGU
# Out:
# 100%|██████████████████████████████████| 86337/86337 [00:01<00:00, 73472.01it/s]

# %%
print('kitab_yurd:',len(azbook_kitabyurdu))
print('ebooks:',len(azbook_ebooks))
print('anl:',len(azbook_anl))
print('axar_az:',len(axar_az))
print('wiki:',len(az_wiki))
print('lent_az:',len(lent_az))
print('kulis_az:',len(kulis_az))
# Out:
# kitab_yurd: 86337
# ebooks: 1139591
# anl: 314804
# axar_az: 143448
# wiki: 98882
# lent_az: 62622
# kulis_az: 30808

# %%
final_list = azbook_kitabyurdu.append(azbook_ebooks+azbook_anl+
                                      axar_az+az_wiki+lent_az+kulis_az)

# %%
final_list = []

final_list.append(azbook_ebooks+azbook_anl+
                                      axar_az+az_wiki+lent_az+kulis_az+azbook_kitabyurdu)

# %%
len(final_list[0])
# Out:
# 1876492

# %%
final_list = final_list[0]

# %%
len(final_list)
# Out:
# 1876492

# %%
total_sum = len(kulis_az) + len(lent_az) + len(az_wiki) + len(axar_az) + len(azbook_anl) + len(azbook_ebooks) + len(azbook_kitabyurdu)

# %%
print('Cemi:', total_sum)
# Out:
# Cemi: 1876492

# %%
azcorpus = {
"corpus_name": "azcorpus",
"language": "Azerbaijani",
"description": "azcorpus is the largest collection of Azerbaijani texts. The corpus is designed to be a balanced, large scale (1.8 million documents) and general-purpose corpus for contemporary Azerbaijani.",
"creation_date": "2022-03-28",

"version":0.1,
"authors": [
{
"name": "Huseyn Kishiyev",
"affiliation": "Atilim University Faculty of Engineering, Department of Software Engineering"
},
{
"name": "Jafar Isbarov",
"affiliation": "Prodata LLC, Azerbaijan"
}

,

{
"name": "Kanan Suleymanli",
"affiliation": "Department of Geoscience Science, King Fahd University of Petroleum and Minerals (KFUPM), Saudi Arabia"
}

,
{
"name": "Leyla Eminova",
"affiliation": "School of Science and Engineering, Khazar University"
}

,
{
"name": "Nijat Zeynalov",
"affiliation": "Azerconnect LLC, Azerbaijan"
},

{
"name": "Khazar Heydarli",
"affiliation": "Faculty of Mechanic and Information Technology, Department of Information Technology at University of Architecture and Construction"
}
]}

# %%
azcorpus['documents'] = final_list

# %%
azcorpus
# Out:
# {'corpus_name': 'azcorpus',
#  'language': 'Azerbaijani',
#  'description': 'azcorpus is the largest collection of Azerbaijani texts. The corpus is designed to be a balanced, large scale (1.8 million documents) and general-purpose corpus for contemporary Azerbaijani.',
#  'creation_date': '2022-03-28',
#  'version': 0.1,
#  'authors': [{'name': 'Huseyn Kishiyev',
#    'affiliation': 'Atilim University Faculty of Engineering, Department of Software Engineering'},
#   {'name': 'Jafar Isbarov', 'affiliation': 'Prodata LLC, Azerbaijan'},
#   {'name': 'Kanan Suleymanli',
#    'affiliation': 'Department of Geoscience Science, King Fahd University of Petroleum and Minerals (KFUPM), Saudi Arabia'},
#   {'name': 'Leyla Eminova',
#    'affiliation': 'School of Science and Engineering, Khazar University'},
#   {'name': 'Nijat Zeynalov', 'affiliation': 'Azerconnect LLC, Azerbaijan'},
#   {'name': 'Khazar Heydarli',
# ...

# %% [markdown]
# # Reliability:
#
# az_news = 5
#
# az_books = 3
#
# az_wiki = 4

# %%
os.chdir('/home/g202103810/Desktop/AZGPT_Corpus')

# %%
import json 

with open("az_corpus.json","w") as fp:
    json.dump(azcorpus,fp)

# %%
cd
# Out:
# /home/g202103810

# %%
print(os.getcwd())
# Out:
# /home/g202103810/Desktop/AZGPT_Corpus
